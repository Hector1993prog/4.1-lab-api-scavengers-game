# %%
import json
import requests as rq

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
# %pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\héctor\appdata\roaming\python\python39\site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

# %%
pwd
# Out:
# 'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\Labs\\Semana 4\\4.1-lab-api-scavengers-game\\your-code'

# %%
with open(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Labs\Semana 4\4.1-lab-api-scavengers-game\your-code\token.txt', 'r') as f:
    token = f.read()

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
main_lab= 'https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/3.4-lab-mongo/forks'

# %%
rq.get(main_lab)
# Out:
# <Response [200]>

# %%
res = requests.get('https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/3.4-lab-mongo/forks')

# %%
res.json()
# Out:
# [{'id': 561475587,
#   'node_id': 'R_kgDOIXdwAw',
#   'name': '3.4-lab-mongo',
#   'full_name': 'Rmp2/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'Rmp2',
#    'id': 114113071,
#    'node_id': 'U_kgDOBs06Lw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114113071?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rmp2',
#    'html_url': 'https://github.com/Rmp2',
#    'followers_url': 'https://api.github.com/users/Rmp2/followers',
#    'following_url': 'https://api.github.com/users/Rmp2/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Rmp2/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Rmp2/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Rmp2/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Rmp2/orgs',
#    'repos_url': 'https://api.github.com/users/Rmp2/repos',
#    'events_url': 'https://api.github.com/users/Rmp2/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Rmp2/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Rmp2/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Rmp2/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T19:19:03Z',
#   'updated_at': '2022-11-03T21:40:29Z',
#   'pushed_at': '2022-11-03T21:40:24Z',
#   'git_url': 'git://github.com/Rmp2/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:Rmp2/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/Rmp2/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/Rmp2/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18662,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561348905,
#   'node_id': 'R_kgDOIXWBKQ',
#   'name': '3.4-lab-mongo',
#   'full_name': 'kranieel/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'kranieel',
#    'id': 112859701,
#    'node_id': 'U_kgDOBroaNQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112859701?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kranieel',
#    'html_url': 'https://github.com/kranieel',
#    'followers_url': 'https://api.github.com/users/kranieel/followers',
#    'following_url': 'https://api.github.com/users/kranieel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kranieel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kranieel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kranieel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kranieel/orgs',
#    'repos_url': 'https://api.github.com/users/kranieel/repos',
#    'events_url': 'https://api.github.com/users/kranieel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kranieel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/kranieel/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/kranieel/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T13:55:37Z',
#   'updated_at': '2022-08-25T10:33:04Z',
#   'pushed_at': '2022-08-30T11:10:51Z',
#   'git_url': 'git://github.com/kranieel/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:kranieel/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/kranieel/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/kranieel/3.4-lab-mongo',
#   'homepage': None,
#   'size': 17897,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561296661,
#   'node_id': 'R_kgDOIXS1FQ',
#   'name': '3.4-lab-mongo',
#   'full_name': 'FrankOballe/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'FrankOballe',
#    'id': 114352562,
#    'node_id': 'U_kgDOBtDhsg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114352562?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FrankOballe',
#    'html_url': 'https://github.com/FrankOballe',
#    'followers_url': 'https://api.github.com/users/FrankOballe/followers',
#    'following_url': 'https://api.github.com/users/FrankOballe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/FrankOballe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/FrankOballe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/FrankOballe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/FrankOballe/orgs',
#    'repos_url': 'https://api.github.com/users/FrankOballe/repos',
#    'events_url': 'https://api.github.com/users/FrankOballe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/FrankOballe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/FrankOballe/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/FrankOballe/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T11:44:40Z',
#   'updated_at': '2022-11-03T14:35:11Z',
#   'pushed_at': '2022-11-03T14:35:06Z',
#   'git_url': 'git://github.com/FrankOballe/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:FrankOballe/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/FrankOballe/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/FrankOballe/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18758,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561292709,
#   'node_id': 'R_kgDOIXSlpQ',
#   'name': '3.4-lab-mongo',
#   'full_name': 'LuciaMPallares/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'LuciaMPallares',
#    'id': 114522768,
#    'node_id': 'U_kgDOBtN6kA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114522768?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuciaMPallares',
#    'html_url': 'https://github.com/LuciaMPallares',
#    'followers_url': 'https://api.github.com/users/LuciaMPallares/followers',
#    'following_url': 'https://api.github.com/users/LuciaMPallares/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LuciaMPallares/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LuciaMPallares/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LuciaMPallares/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LuciaMPallares/orgs',
#    'repos_url': 'https://api.github.com/users/LuciaMPallares/repos',
#    'events_url': 'https://api.github.com/users/LuciaMPallares/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LuciaMPallares/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/LuciaMPallares/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/LuciaMPallares/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T11:33:31Z',
#   'updated_at': '2022-11-03T17:08:17Z',
#   'pushed_at': '2022-11-03T17:08:12Z',
#   'git_url': 'git://github.com/LuciaMPallares/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:LuciaMPallares/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/LuciaMPallares/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/LuciaMPallares/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18739,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561292625,
#   'node_id': 'R_kgDOIXSlUQ',
#   'name': '3.4-lab-mongo',
#   'full_name': 'Jorlo0412/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'Jorlo0412',
#    'id': 114603199,
#    'node_id': 'U_kgDOBtS0vw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114603199?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jorlo0412',
#    'html_url': 'https://github.com/Jorlo0412',
#    'followers_url': 'https://api.github.com/users/Jorlo0412/followers',
#    'following_url': 'https://api.github.com/users/Jorlo0412/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jorlo0412/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jorlo0412/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jorlo0412/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jorlo0412/orgs',
#    'repos_url': 'https://api.github.com/users/Jorlo0412/repos',
#    'events_url': 'https://api.github.com/users/Jorlo0412/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jorlo0412/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jorlo0412/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jorlo0412/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T11:33:16Z',
#   'updated_at': '2022-08-25T10:33:04Z',
#   'pushed_at': '2022-08-30T11:10:51Z',
#   'git_url': 'git://github.com/Jorlo0412/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:Jorlo0412/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/Jorlo0412/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/Jorlo0412/3.4-lab-mongo',
#   'homepage': None,
#   'size': 17897,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561291847,
#   'node_id': 'R_kgDOIXSiRw',
#   'name': '3.4-lab-mongo',
#   'full_name': 'Hector1993prog/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'Hector1993prog',
#    'id': 115273393,
#    'node_id': 'U_kgDOBt7usQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115273393?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hector1993prog',
#    'html_url': 'https://github.com/Hector1993prog',
#    'followers_url': 'https://api.github.com/users/Hector1993prog/followers',
#    'following_url': 'https://api.github.com/users/Hector1993prog/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Hector1993prog/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Hector1993prog/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Hector1993prog/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Hector1993prog/orgs',
#    'repos_url': 'https://api.github.com/users/Hector1993prog/repos',
#    'events_url': 'https://api.github.com/users/Hector1993prog/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Hector1993prog/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Hector1993prog/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Hector1993prog/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T11:30:55Z',
#   'updated_at': '2022-11-03T14:20:12Z',
#   'pushed_at': '2022-11-03T14:20:07Z',
#   'git_url': 'git://github.com/Hector1993prog/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:Hector1993prog/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/Hector1993prog/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/Hector1993prog/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18683,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 561291767,
#   'node_id': 'R_kgDOIXSh9w',
#   'name': '3.4-lab-mongo',
#   'full_name': 'marcosfrmu/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'marcosfrmu',
#    'id': 115036003,
#    'node_id': 'U_kgDOBttPYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115036003?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcosfrmu',
#    'html_url': 'https://github.com/marcosfrmu',
#    'followers_url': 'https://api.github.com/users/marcosfrmu/followers',
#    'following_url': 'https://api.github.com/users/marcosfrmu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/marcosfrmu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/marcosfrmu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/marcosfrmu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/marcosfrmu/orgs',
#    'repos_url': 'https://api.github.com/users/marcosfrmu/repos',
#    'events_url': 'https://api.github.com/users/marcosfrmu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/marcosfrmu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/marcosfrmu/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/marcosfrmu/3.4-lab-mongo/deployments',
#   'created_at': '2022-11-03T11:30:40Z',
#   'updated_at': '2022-11-04T00:12:06Z',
#   'pushed_at': '2022-11-04T00:12:01Z',
#   'git_url': 'git://github.com/marcosfrmu/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:marcosfrmu/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/marcosfrmu/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/marcosfrmu/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18787,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 529155801,
#   'node_id': 'R_kgDOH4pG2Q',
#   'name': '3.4-lab-mongo',
#   'full_name': 'joserojas95/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'joserojas95',
#    'id': 110819726,
#    'node_id': 'U_kgDOBpr5jg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110819726?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joserojas95',
#    'html_url': 'https://github.com/joserojas95',
#    'followers_url': 'https://api.github.com/users/joserojas95/followers',
#    'following_url': 'https://api.github.com/users/joserojas95/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joserojas95/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joserojas95/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joserojas95/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joserojas95/orgs',
#    'repos_url': 'https://api.github.com/users/joserojas95/repos',
#    'events_url': 'https://api.github.com/users/joserojas95/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joserojas95/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/joserojas95/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/joserojas95/3.4-lab-mongo/deployments',
#   'created_at': '2022-08-26T07:16:25Z',
#   'updated_at': '2022-08-26T07:19:09Z',
#   'pushed_at': '2022-08-26T07:19:06Z',
#   'git_url': 'git://github.com/joserojas95/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:joserojas95/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/joserojas95/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/joserojas95/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18673,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 528864291,
#   'node_id': 'R_kgDOH4XUIw',
#   'name': '3.4-lab-mongo',
#   'full_name': 'antlopal3rd/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'antlopal3rd',
#    'id': 108612580,
#    'node_id': 'U_kgDOBnlL5A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108612580?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antlopal3rd',
#    'html_url': 'https://github.com/antlopal3rd',
#    'followers_url': 'https://api.github.com/users/antlopal3rd/followers',
#    'following_url': 'https://api.github.com/users/antlopal3rd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/antlopal3rd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/antlopal3rd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/antlopal3rd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/antlopal3rd/orgs',
#    'repos_url': 'https://api.github.com/users/antlopal3rd/repos',
#    'events_url': 'https://api.github.com/users/antlopal3rd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/antlopal3rd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/antlopal3rd/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/antlopal3rd/3.4-lab-mongo/compare/{base}...{head}',
# ...
#    'followers_url': 'https://api.github.com/users/MiguelBeitia/followers',
#    'following_url': 'https://api.github.com/users/MiguelBeitia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MiguelBeitia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MiguelBeitia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MiguelBeitia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MiguelBeitia/orgs',
#    'repos_url': 'https://api.github.com/users/MiguelBeitia/repos',
#    'events_url': 'https://api.github.com/users/MiguelBeitia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MiguelBeitia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/MiguelBeitia/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/MiguelBeitia/3.4-lab-mongo/deployments',
#   'created_at': '2022-08-25T12:52:56Z',
#   'updated_at': '2022-08-25T17:12:17Z',
#   'pushed_at': '2022-08-25T17:12:13Z',
#   'git_url': 'git://github.com/MiguelBeitia/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:MiguelBeitia/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/MiguelBeitia/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/MiguelBeitia/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18704,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 528846932,
#   'node_id': 'R_kgDOH4WQVA',
#   'name': '3.4-lab-mongo',
#   'full_name': 'PabloGR1/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'PabloGR1',
#    'id': 107139579,
#    'node_id': 'U_kgDOBmLR-w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107139579?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PabloGR1',
#    'html_url': 'https://github.com/PabloGR1',
#    'followers_url': 'https://api.github.com/users/PabloGR1/followers',
#    'following_url': 'https://api.github.com/users/PabloGR1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PabloGR1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PabloGR1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PabloGR1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PabloGR1/orgs',
#    'repos_url': 'https://api.github.com/users/PabloGR1/repos',
#    'events_url': 'https://api.github.com/users/PabloGR1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PabloGR1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/PabloGR1/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/PabloGR1/3.4-lab-mongo/deployments',
#   'created_at': '2022-08-25T12:44:50Z',
#   'updated_at': '2022-08-25T14:06:15Z',
#   'pushed_at': '2022-08-25T16:15:42Z',
#   'git_url': 'git://github.com/PabloGR1/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:PabloGR1/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/PabloGR1/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/PabloGR1/3.4-lab-mongo',
#   'homepage': None,
#   'size': 33147,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 528807677,
#   'node_id': 'R_kgDOH4T2_Q',
#   'name': '3.4-lab-mongo',
#   'full_name': 'Vert-ix/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'Vert-ix',
#    'id': 108289867,
#    'node_id': 'U_kgDOBnRfSw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108289867?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vert-ix',
#    'html_url': 'https://github.com/Vert-ix',
#    'followers_url': 'https://api.github.com/users/Vert-ix/followers',
#    'following_url': 'https://api.github.com/users/Vert-ix/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Vert-ix/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Vert-ix/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Vert-ix/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Vert-ix/orgs',
#    'repos_url': 'https://api.github.com/users/Vert-ix/repos',
#    'events_url': 'https://api.github.com/users/Vert-ix/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Vert-ix/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Vert-ix/3.4-lab-mongo',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo',
#   'forks_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/forks',
#   'keys_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/teams',
#   'hooks_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/events',
#   'assignees_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/tags',
#   'blobs_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/languages',
#   'stargazers_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/subscription',
#   'commits_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/merges',
#   'archive_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/downloads',
#   'issues_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Vert-ix/3.4-lab-mongo/deployments',
#   'created_at': '2022-08-25T10:50:01Z',
#   'updated_at': '2022-08-25T17:13:28Z',
#   'pushed_at': '2022-08-25T17:13:25Z',
#   'git_url': 'git://github.com/Vert-ix/3.4-lab-mongo.git',
#   'ssh_url': 'git@github.com:Vert-ix/3.4-lab-mongo.git',
#   'clone_url': 'https://github.com/Vert-ix/3.4-lab-mongo.git',
#   'svn_url': 'https://github.com/Vert-ix/3.4-lab-mongo',
#   'homepage': None,
#   'size': 18720,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]

# %%
res.json()[0]['language']
# Out:
# 'Jupyter Notebook'

# %%
li= []
for i in range(len (res.json())):
    li.append(res.json()[i]["language"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 li= []
# ----> 2 for i in range(len (res.json())):
#       3     li.append(res.json()[i]["language"])
#
# NameError: name 'res' is not defined

# %%
lista = []
for i in res.json():
    lista.append(i['language'])

# %%
li
# Out:
# ['Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']

# %%
lista
# Out:
# ['Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']
